# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Samantha St. Amand**
# <br>
# Data Scientist

# %% [markdown]
# *I am interested in Data Science because I love sourcing and analzying information to provide fact-based information to decision makers.*

# %% [markdown]
# ### Cell 5 will give you the answer to life, the universe and everything

# %%
10*4 + 6/3
# Out:
# 42.0

# %% [markdown]
# **Grocery List**
# - Eggs
# - Bread
# - Yogurt
#
# [Link to Coursera](https://www.coursera.org/)
#
# **Image of a cute cat**
# ![Cute Cat](https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/cute-cat-photos-1593441022.jpg?crop=0.670xw:1.00xh;0.167xw,0&resize=640:*)
